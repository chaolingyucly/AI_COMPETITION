# %%
import pandas as pd
import datetime

# %%
file2_name = "daily_trading_info_2019-2020.xlsx"
file2 = pd.read_excel(file2_name, sheet_name = None)
company_index = []
company_index = list(file2.keys())[:] #sheet name

# %%
from talib import abstract

# %%
pd.read_excel(company_index[0]+".xlsx")
# Out:
#            date       open       high        low      close   volume  \
# 0    2014-01-02  21.309999  21.700001  21.230000  21.459999  5096443
# 1    2014-01-03  21.400000  21.450001  20.370001  20.790001  9945683
# 2    2014-01-06  20.680000  20.680000  20.219999  20.240000  5171376
# 3    2014-01-07  20.100000  20.250000  19.860001  20.000000  5364241
# 4    2014-01-08  20.000000  20.389999  20.000000  20.230000  5186841
# ...         ...        ...        ...        ...        ...      ...
# 1517 2020-03-25  24.600000  24.850000  24.500000  24.799999  7072723
# 1518 2020-03-26  24.620001  25.290001  24.580000  25.129999  8346083
# 1519 2020-03-27  25.320000  25.799999  25.150000  25.180000  8794212
# 1520 2020-03-30  25.150000  25.570000  24.950001  25.450001  8179292
# 1521 2020-03-31  25.500000  25.540001  25.150000  25.350000  5331630
#
#             ma5    ma10       ma15       MOM  ...      MFI.1       OBV.1  \
# ...

# %%
df = pd.read_excel(company_index[0]+".xlsx")

# %%
inputs = {
    'open': df["open"],
    'high': df["high"],
    'low':  df["low"],
    'close': df["close"],
    'volume': df["volume"]
}
# uses close prices (default)
out1 = abstract.MOM(inputs, timeperiod=12)
out2 = abstract.RSI(inputs, timeperiod=12)
out3 = abstract.CMO(inputs, timeperiod=12)
#out4slowk, out4slowd = abstract.STOCH(inputs, fastk_period=9, slowk_period=3, slowk_matype=0, slowd_period=3, slowd_matype=0)
#out5macd, out5macdsignal, out5macdhist = abstract.MACD(inputs, fastperiod=6, slowperiod=12, signalperiod=9)
#out6 = abstract.ADXR(inputs, timeperiod=12)
#out7 = abstract.DX(inputs, timeperiod=12)
#out8 = abstract.MFI(inputs, timeperiod=12)
#out9 = abstract.OBV(inputs)
#out10 = abstract.AD(inputs)
#out11 = abstract.WILLR(inputs, timeperiod=12)

# %%
pd.DataFrame(out1, columns=["MOM"]).head(20)

# %%
pd.DataFrame(out2, columns=["RSI"]).head(20)

# %%
pd.DataFrame(out3, columns=["CMO"]).head(20)

# %%
#pd.DataFrame(out6, columns=["ADXR"]).head(50)
# Out:
#          ADXR
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        NaN
# 24        NaN
# 25        NaN
# 26        NaN
# 27        NaN
# 28        NaN
# 29        NaN
# 30        NaN
# 31        NaN
# 32        NaN
# 33        NaN
# 34  36.782542
# 35  35.728597
# 36  35.237857
# 37  34.358534
# 38  33.434024
# 39  33.309391
# 40  33.607653
# 41  32.246287
# 42  31.361886
# 43  31.002175
# 44  31.169920
# 45  31.160774
# 46  31.339185
# 47  31.770278
# 48  30.962427
# 49  30.423419

# %%
#pd.DataFrame(out7, columns=["DX"]).head(20)
# Out:
#            DX
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12  51.693510
# 13  36.650368
# 14  35.027257
# 15  33.300085
# 16  42.695938
# 17  49.028927
# 18  49.028927
# 19  51.544608

# %%
#pd.DataFrame(out8, columns=["MFI"]).head(20)
# Out:
#           MFI
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12  26.543920
# 13  35.582571
# 14  44.665169
# 15  45.890305
# 16  33.721294
# 17  31.995213
# 18  43.744449
# 19  42.161150

# %%
#pd.DataFrame(out9, columns=["OBV"]).head(20)
# Out:
#            OBV
# 0    5096443.0
# 1   -4849240.0
# 2  -10020616.0
# 3  -15384857.0
# 4  -10198016.0
# 5  -14022843.0
# 6  -23166243.0
# 7  -27450048.0
# 8  -24023898.0
# 9  -19145713.0
# 10 -16214089.0
# 11 -19027772.0
# 12 -23648791.0
# 13 -20737100.0
# 14 -16134570.0
# 15 -20089900.0
# 16 -28638417.0
# 17 -35736370.0
# 18 -30308563.0
# 19 -36764787.0

# %%
#pd.DataFrame(out10, columns=["AD"]).head(20)
# Out:
#               AD
# 0  -1.084578e+05
# 1  -2.318608e+06
# 2  -7.040289e+06
# 3  -8.553291e+06
# 4  -7.622322e+06
# 5  -1.025187e+07
# 6  -1.451878e+07
# 7  -1.259846e+07
# 8  -1.026245e+07
# 9  -8.636388e+06
# 10 -8.981293e+06
# 11 -1.001070e+07
# 12 -1.101526e+07
# 13 -8.922480e+06
# 14 -4.575652e+06
# 15 -7.359007e+06
# 16 -1.253990e+07
# 17 -1.834734e+07
# 18 -2.119052e+07
# 19 -2.433586e+07

# %%
#pd.DataFrame(out11, columns=["WILLR"]).head(20)
# Out:
#         WILLR
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11 -71.897811
# 12 -81.124462
# 13 -40.697690
# 14 -20.279647
# 15 -32.867078
# 16 -56.390900
# 17 -90.756255
# 18 -89.473772
# 19 -92.125957

# %%
#out1

# %%
pd.concat([df, pd.DataFrame(out1, columns=["MOM"])\
             , pd.DataFrame(out2, columns=["RSI"])\
             , pd.DataFrame(out3, columns=["CMO"])], axis=1).head(50)


#out1 = abstract.MOM(inputs, timeperiod=12)
#out2 = abstract.RSI(inputs, timeperiod=12)
#out3 = abstract.CMO(inputs, timeperiod=12)
#out4slowk, out4slowd = abstract.STOCH(inputs, fastk_period=9, slowk_period=3, slowk_matype=0, slowd_period=3, slowd_matype=0)
#out5macd, out5macdsignal, out5macdhist = abstract.MACD(inputs, fastperiod=6, slowperiod=12, signalperiod=9)
#out6 = abstract.ADXR(inputs, timeperiod=12)
#out7 = abstract.DX(inputs, timeperiod=12)
#out8 = abstract.MFI(inputs, timeperiod=12)
#out9 = abstract.OBV(inputs)
#out10 = abstract.AD(inputs)
#out11 = abstract.WILLR(inputs, timeperiod=12)
# Out:
#          date       open       high        low      close    volume     ma5  \
# 0  2014-01-02  21.309999  21.700001  21.230000  21.459999   5096443     NaN
# 1  2014-01-03  21.400000  21.450001  20.370001  20.790001   9945683     NaN
# 2  2014-01-06  20.680000  20.680000  20.219999  20.240000   5171376     NaN
# 3  2014-01-07  20.100000  20.250000  19.860001  20.000000   5364241     NaN
# 4  2014-01-08  20.000000  20.389999  20.000000  20.230000   5186841  20.544
# 5  2014-01-09  20.200001  20.290001  19.969999  20.020000   3824827  20.256
# 6  2014-01-10  19.900000  20.010000  18.959999  19.240000   9143400  19.946
# 7  2014-01-13  19.299999  19.299999  19.010000  19.219999   4283805  19.742
# 8  2014-01-14  19.219999  19.559999  19.120001  19.490000   3426150  19.640
# 9  2014-01-15  19.490000  20.000000  19.490000  19.830000   4878185  19.560
# 10 2014-01-16  19.840000  20.100000  19.760000  19.910000   2931624  19.538
# ...

# %% [markdown]
# Starting calculating

# %%
for w in range(0, len(company_index)):
    df = pd.read_excel(company_index[w]+".xlsx")
    inputs = {
    'open': df["open"],
    'high': df["high"],
    'low':  df["low"],
    'close': df["close"],
    'volume': df["volume"]
    }
    # uses close prices (default)
    out1 = abstract.MOM(inputs, timeperiod=12)
    out2 = abstract.RSI(inputs, timeperiod=12)
    out3 = abstract.CMO(inputs, timeperiod=12)
    a = pd.DataFrame(out1, columns=["MOM"])
    b = pd.DataFrame(out2, columns=["RSI"])
    c = pd.DataFrame(out3, columns=["CMO"])
    pd.concat([df,a , b, c], axis=1).to_excel(company_index[w]+".xlsx", \
                                              sheet_name = company_index[w], index=False)
    if(w%100==0):
        print(w)        
        
#out1 = abstract.MOM(inputs, timeperiod=12)
#out2 = abstract.RSI(inputs, timeperiod=12)
#out3 = abstract.CMO(inputs, timeperiod=12)
#out4 = abstract.STOCH(inputs, fastk_period=9, slowk_period=3, slowk_matype=0, slowd_period=3, slowd_matype=0)
#out5 = abstract.MACD(inputs, fastperiod=6, slowperiod=12, signalperiod=9)
#out6 = abstract.ADXR(inputs, timeperiod=14)
#out7 = abstract.DX(inputs, timeperiod=14)
#out8 = abstract.MFI(inputs, timeperiod=14)
#out9 = abstract.OBV(inputs)
#out10 = abstract.AD(inputs)
#out11 = abstract.WILLR(inputs, timeperiod=14)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700

# %% [markdown]
# Assign the features to the train file with labels

# %%
train_set = pd.read_excel("strategy_results_train_max.xlsx")

# %%
import copy

# %%
dataset = copy.deepcopy(train_set)

# %%
temp = []
for i in range(0, dataset.shape[0]):
# for i in range(0, 1):
    if(i%1000==0):
        print(i, datetime.datetime.now())
    trade_company = dataset.iloc[i][0].split("_")[0]
    trade_date    = dataset.iloc[i][0].split("_")[1]
    df = pd.read_excel(trade_company+".xlsx")
    trade_date_datetime = datetime.date(int(trade_date[:4]), int(trade_date[4:]), 1) - datetime.timedelta(days=1)
    lower_index = 0
    for index in range(0, df.shape[0]):
        if(df["date"].iloc[index]< trade_date_datetime):
            lower_index = index
        else:
            break
#     print(list(df.iloc[lower_index, :]))
    temp.append(list(df.iloc[lower_index, :]))
# Out:
# 0 2020-06-15 23:56:33.036783
# 1000 2020-06-16 00:06:42.666193
# 2000 2020-06-16 00:16:42.130523
# 3000 2020-06-16 00:26:46.779573
# 4000 2020-06-16 00:36:53.864130
# 5000 2020-06-16 00:46:35.597880
# 6000 2020-06-16 00:56:51.766017
# 7000 2020-06-16 01:06:32.987967
# 8000 2020-06-16 01:16:36.375052
# 9000 2020-06-16 01:26:49.904633
# 10000 2020-06-16 01:36:29.910562
# 11000 2020-06-16 01:45:59.015849
# 12000 2020-06-16 01:56:17.579488
# 13000 2020-06-16 02:06:30.361872
# 14000 2020-06-16 02:16:42.105372
# 15000 2020-06-16 02:26:53.760339
# 16000 2020-06-16 02:37:06.273220
# 17000 2020-06-16 02:47:18.151870
# 18000 2020-06-16 02:57:12.278523
# 19000 2020-06-16 03:07:39.104779
# 20000 2020-06-16 03:17:27.906833
# 21000 2020-06-16 03:27:29.024964
# 22000 2020-06-16 03:37:23.342878
# 23000 2020-06-16 03:47:24.693787
# 24000 2020-06-16 03:57:30.668912
# 25000 2020-06-16 04:07:07.987739
# 26000 2020-06-16 04:17:03.673187
# 27000 2020-06-16 04:26:23.130705
# ...

# %%
pd.DataFrame(temp).to_excel("train_output_mul.xlsx", index=False)

# %%
# df.iloc[lower_index, :]

# %%
# trade_date_datetime

# %%
# df["date"][0] < trade_date_datetime

# %%
#pd.concat(,axis=1)
#train_set = pd.read_excel("strategy_results_train.xlsx")

# %%
testset = pd.read_excel("sampleSubmission.xlsx")

# %%
testset.head()
# Out:
#                    id  label
# 0  SHSE.600085_201901      0
# 1  SHSE.600085_201902      0
# 2  SHSE.600085_201903      0
# 3  SHSE.600085_201904      0
# 4  SHSE.600085_201905      0

# %%
temp = []
for i in range(0, testset.shape[0]):
# for i in range(0, 10):
    if(i%1000==0):
        print(i, datetime.datetime.now())
    trade_company = testset.iloc[i][0].split("_")[0]
    trade_date    = testset.iloc[i][0].split("_")[1]
    df = pd.read_excel(trade_company+".xlsx")
    trade_date_datetime = datetime.date(int(trade_date[:4]), int(trade_date[4:]), 1) - datetime.timedelta(days=1)
    lower_index = 0
    for index in range(0, df.shape[0]):
        if(df["date"].iloc[index]< trade_date_datetime):
            lower_index = index
        else:
            break
#     print(list(df.iloc[lower_index, :]))
    if(lower_index==0):
        temp.append(dash = ["-","","","","","","","",""])
    else:
        temp.append(list(df.iloc[lower_index, :]))
# Out:
# 0 2020-06-16 05:12:46.425067
# 1000 2020-06-16 05:22:59.382387
# 2000 2020-06-16 05:32:34.301649
# 3000 2020-06-16 05:42:21.281574
# 4000 2020-06-16 05:51:11.118493
# 5000 2020-06-16 06:01:31.287931
# 6000 2020-06-16 06:11:52.564253
# 7000 2020-06-16 06:21:47.041121
# 8000 2020-06-16 06:31:40.763926
# 9000 2020-06-16 06:41:23.829749
# 10000 2020-06-16 06:51:10.994590
# 11000 2020-06-16 06:59:42.503697

# %%
pd.DataFrame(temp).to_excel("test_output_mul.xlsx", index=False)

# %%
temp[0]
# Out:
# [Timestamp('2018-12-28 00:00:00'),
#  27.18000030517578,
#  27.57999992370605,
#  26.98999977111816,
#  27.5,
#  3575585,
#  27.25800018310547,
#  27.57299995422363,
#  28.19799995422363,
#  -1.739999771118161,
#  40.62536249336742,
#  -18.74927501326517,
#  23.36664512099905,
#  35.338823030059,
#  37.96568061452146,
#  1750766779,
#  1661372966.78957,
#  -66.5914347566257,
#  23.36664512099905,
#  35.338823030059,
#  37.96568061452146,
#  1750766779,
#  1661372966.78957,
#  -66.5914347566257,
#  23.36664512099905,
#  35.338823030059,
#  37.96568061452146,
#  1750766779,
#  1661372966.78957,
#  -66.5914347566257,
#  23.36664512099905,
#  35.338823030059,
#  37.96568061452146,
#  1750766779,
#  1661372966.78957,
#  -66.5914347566257]
